# %%
import numpy as np
import pandas as pd
import json
from matplotlib import pyplot as plt

# %%
kf_consumer_result_path = "../kf-consumer-result.txt"
kf_producer_result_path = "../kf-producer-result.txt"
sq_consumer_result_path = "../sq-consumer-result.txt"
sq_producer_result_path = "../sq-producer-result.txt"

# %%
def read_jsons(path):
    # Using readlines() 
    file1 = open(path, 'r') 
    Lines = file1.readlines() 
    
    results = []
    
    for line in Lines: 
        result = json.loads(line.strip())
        results.append(result)
    return results

# %%
kf_consumer_results = read_jsons(kf_consumer_result_path)
kf_producer_results = read_jsons(kf_producer_result_path)

sq_consumer_results = read_jsons(sq_consumer_result_path)
sq_producer_results = read_jsons(sq_producer_result_path)

num_consumers = list(map(lambda i: i["NumClient"], kf_consumer_results))

# %%
plt.plot(num_consumers, list(map(lambda i: i["AvgTime"], kf_consumer_results)))
plt.plot(num_consumers, list(map(lambda i: i["AvgTime"], kf_producer_results)))
plt.plot(num_consumers, list(map(lambda i: i["AvgTime"], sq_producer_results)))
plt.plot(num_consumers, list(map(lambda i: i["AvgTime"], sq_consumer_results)))
plt.xlabel('Number of Consumers')
plt.ylabel('Elapsed Time(second)')
plt.legend(['Kafka-Producer', 'Kafka-Consumer', 'ShapleQ-Producer', 'ShapleQ-Consumer'])
plt.show()
